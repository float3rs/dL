# %%
import pandas
import calendar
import matplotlib
from matplotlib import pyplot

# %%
# %matplotlib inline

# %%
df = pandas.read_csv('full.txt', header=None, skiprows=2, sep='\s+', names=['year', 'month', 'day', 'hour', 'minute', 'second', 'latitude', 'lotitude', 'depth', 'magnitude'])

# %%
df
# Out:
#         year month  day  hour  minute  second  latitude  lotitude  depth  \
# 0       1964   FEB   24    23      30    25.0   38.9000   23.9000     10
# 1       1964   APR   11    16       0     0.0   39.7500   25.2500     10
# 2       1964   APR   21     8      14    40.0   38.5000   22.2500     10
# 3       1964   APR   24     3      49    58.0   38.0000   21.8000     10
# 4       1964   APR   29     4      21     0.0   39.2500   23.7500     10
# ...      ...   ...  ...   ...     ...     ...       ...       ...    ...
# 313395  2021   APR    9     5       0     7.4   39.7856   21.9081      5
# 313396  2021   APR    9     5       0    21.9   39.7920   21.9328      5
# 313397  2021   APR    9     5       1     6.5   39.7160   22.1947      8
# 313398  2021   APR    9     5       2     5.6   39.7929   21.9154      6
# 313399  2021   APR    9     5      15     5.0   39.8007   21.8948      7
#
#         magnitude
# 0             5.3
# 1             5.7
# 2             4.5
# ...

# %%
df.index.name = 'id'

# %%
df
# Out:
#         year month  day  hour  minute  second  latitude  lotitude  depth  \
# id
# 0       1964   FEB   24    23      30    25.0   38.9000   23.9000     10
# 1       1964   APR   11    16       0     0.0   39.7500   25.2500     10
# 2       1964   APR   21     8      14    40.0   38.5000   22.2500     10
# 3       1964   APR   24     3      49    58.0   38.0000   21.8000     10
# 4       1964   APR   29     4      21     0.0   39.2500   23.7500     10
# ...      ...   ...  ...   ...     ...     ...       ...       ...    ...
# 313395  2021   APR    9     5       0     7.4   39.7856   21.9081      5
# 313396  2021   APR    9     5       0    21.9   39.7920   21.9328      5
# 313397  2021   APR    9     5       1     6.5   39.7160   22.1947      8
# 313398  2021   APR    9     5       2     5.6   39.7929   21.9154      6
# 313399  2021   APR    9     5      15     5.0   39.8007   21.8948      7
#
#         magnitude
# id
# 0             5.3
# 1             5.7
# 2             4.5
# ...

# %%
df['month'] = df['month'].str.title()

# %%
df
# Out:
#         year month  day  hour  minute  second  latitude  lotitude  depth  \
# id
# 0       1964   Feb   24    23      30    25.0   38.9000   23.9000     10
# 1       1964   Apr   11    16       0     0.0   39.7500   25.2500     10
# 2       1964   Apr   21     8      14    40.0   38.5000   22.2500     10
# 3       1964   Apr   24     3      49    58.0   38.0000   21.8000     10
# 4       1964   Apr   29     4      21     0.0   39.2500   23.7500     10
# ...      ...   ...  ...   ...     ...     ...       ...       ...    ...
# 313395  2021   Apr    9     5       0     7.4   39.7856   21.9081      5
# 313396  2021   Apr    9     5       0    21.9   39.7920   21.9328      5
# 313397  2021   Apr    9     5       1     6.5   39.7160   22.1947      8
# 313398  2021   Apr    9     5       2     5.6   39.7929   21.9154      6
# 313399  2021   Apr    9     5      15     5.0   39.8007   21.8948      7
#
#         magnitude
# id
# 0             5.3
# 1             5.7
# 2             4.5
# ...

# %%
month_abbr_as_ints = dict((x,y) for (y,x) in enumerate(calendar.month_abbr))
month_abbr_as_ints
# Out:
# {'': 0,
#  'Jan': 1,
#  'Feb': 2,
#  'Mar': 3,
#  'Apr': 4,
#  'May': 5,
#  'Jun': 6,
#  'Jul': 7,
#  'Aug': 8,
#  'Sep': 9,
#  'Oct': 10,
#  'Nov': 11,
#  'Dec': 12}

# %%
df['month'].replace(month_abbr_as_ints, inplace=True)

# %%
df
# Out:
#         year  month  day  hour  minute  second  latitude  lotitude  depth  \
# id
# 0       1964      2   24    23      30    25.0   38.9000   23.9000     10
# 1       1964      4   11    16       0     0.0   39.7500   25.2500     10
# 2       1964      4   21     8      14    40.0   38.5000   22.2500     10
# 3       1964      4   24     3      49    58.0   38.0000   21.8000     10
# 4       1964      4   29     4      21     0.0   39.2500   23.7500     10
# ...      ...    ...  ...   ...     ...     ...       ...       ...    ...
# 313395  2021      4    9     5       0     7.4   39.7856   21.9081      5
# 313396  2021      4    9     5       0    21.9   39.7920   21.9328      5
# 313397  2021      4    9     5       1     6.5   39.7160   22.1947      8
# 313398  2021      4    9     5       2     5.6   39.7929   21.9154      6
# 313399  2021      4    9     5      15     5.0   39.8007   21.8948      7
#
#         magnitude
# id
# 0             5.3
# 1             5.7
# ...

# %%
df['datetime'] = (
    df['year'].astype(str) + '-' + 
    df['month'].astype(str) + '-' +
    df['day'].astype(str) + ' ' +
    df['hour'].astype(str) + ':' +
    df['minute'].astype(str) + ':' +
    df['second'].astype(str)
)

# %%
df
# Out:
#         year  month  day  hour  minute  second  latitude  lotitude  depth  \
# id
# 0       1964      2   24    23      30    25.0   38.9000   23.9000     10
# 1       1964      4   11    16       0     0.0   39.7500   25.2500     10
# 2       1964      4   21     8      14    40.0   38.5000   22.2500     10
# 3       1964      4   24     3      49    58.0   38.0000   21.8000     10
# 4       1964      4   29     4      21     0.0   39.2500   23.7500     10
# ...      ...    ...  ...   ...     ...     ...       ...       ...    ...
# 313395  2021      4    9     5       0     7.4   39.7856   21.9081      5
# 313396  2021      4    9     5       0    21.9   39.7920   21.9328      5
# 313397  2021      4    9     5       1     6.5   39.7160   22.1947      8
# 313398  2021      4    9     5       2     5.6   39.7929   21.9154      6
# 313399  2021      4    9     5      15     5.0   39.8007   21.8948      7
#
#         magnitude              datetime
# id
# ...

# %%
df.drop(columns = ['year', 'month', 'day', 'hour', 'minute', 'second'], inplace = True)

# %%
df
# Out:
#         latitude  lotitude  depth  magnitude              datetime
# id
# 0        38.9000   23.9000     10        5.3  1964-2-24 23:30:25.0
# 1        39.7500   25.2500     10        5.7    1964-4-11 16:0:0.0
# 2        38.5000   22.2500     10        4.5   1964-4-21 8:14:40.0
# 3        38.0000   21.8000     10        5.0   1964-4-24 3:49:58.0
# 4        39.2500   23.7500     10        5.8    1964-4-29 4:21:0.0
# ...          ...       ...    ...        ...                   ...
# 313395   39.7856   21.9081      5        0.6      2021-4-9 5:0:7.4
# 313396   39.7920   21.9328      5        1.5     2021-4-9 5:0:21.9
# 313397   39.7160   22.1947      8        1.0      2021-4-9 5:1:6.5
# 313398   39.7929   21.9154      6        1.0      2021-4-9 5:2:5.6
# 313399   39.8007   21.8948      7        1.2     2021-4-9 5:15:5.0
#
# [313400 rows x 5 columns]

# %%
list(df.columns.values)
# Out:
# ['latitude', 'lotitude', 'depth', 'magnitude', 'datetime']

# %%
df = df[['datetime', 'latitude', 'lotitude', 'depth', 'magnitude']]

# %%
df
# Out:
#                     datetime  latitude  lotitude  depth  magnitude
# id
# 0       1964-2-24 23:30:25.0   38.9000   23.9000     10        5.3
# 1         1964-4-11 16:0:0.0   39.7500   25.2500     10        5.7
# 2        1964-4-21 8:14:40.0   38.5000   22.2500     10        4.5
# 3        1964-4-24 3:49:58.0   38.0000   21.8000     10        5.0
# 4         1964-4-29 4:21:0.0   39.2500   23.7500     10        5.8
# ...                      ...       ...       ...    ...        ...
# 313395      2021-4-9 5:0:7.4   39.7856   21.9081      5        0.6
# 313396     2021-4-9 5:0:21.9   39.7920   21.9328      5        1.5
# 313397      2021-4-9 5:1:6.5   39.7160   22.1947      8        1.0
# 313398      2021-4-9 5:2:5.6   39.7929   21.9154      6        1.0
# 313399     2021-4-9 5:15:5.0   39.8007   21.8948      7        1.2
#
# [313400 rows x 5 columns]

# %%
df.dtypes
# Out:
# datetime      object
# latitude     float64
# lotitude     float64
# depth          int64
# magnitude    float64
# dtype: object

# %%
df['datetime'] = pandas.to_datetime(df['datetime'])

# %%
df
# Out:
#                       datetime  latitude  lotitude  depth  magnitude
# id
# 0      1964-02-24 23:30:25.000   38.9000   23.9000     10        5.3
# 1      1964-04-11 16:00:00.000   39.7500   25.2500     10        5.7
# 2      1964-04-21 08:14:40.000   38.5000   22.2500     10        4.5
# 3      1964-04-24 03:49:58.000   38.0000   21.8000     10        5.0
# 4      1964-04-29 04:21:00.000   39.2500   23.7500     10        5.8
# ...                        ...       ...       ...    ...        ...
# 313395 2021-04-09 05:00:07.400   39.7856   21.9081      5        0.6
# 313396 2021-04-09 05:00:21.900   39.7920   21.9328      5        1.5
# 313397 2021-04-09 05:01:06.500   39.7160   22.1947      8        1.0
# 313398 2021-04-09 05:02:05.600   39.7929   21.9154      6        1.0
# 313399 2021-04-09 05:15:05.000   39.8007   21.8948      7        1.2
#
# [313400 rows x 5 columns]

# %%
df.dtypes
# Out:
# datetime     datetime64[ns]
# latitude            float64
# lotitude            float64
# depth                 int64
# magnitude           float64
# dtype: object

# %%
datetimes = df['datetime']

# %%
datetimes
# Out:
# id
# 0        1964-02-24 23:30:25.000
# 1        1964-04-11 16:00:00.000
# 2        1964-04-21 08:14:40.000
# 3        1964-04-24 03:49:58.000
# 4        1964-04-29 04:21:00.000
#                    ...
# 313395   2021-04-09 05:00:07.400
# 313396   2021-04-09 05:00:21.900
# 313397   2021-04-09 05:01:06.500
# 313398   2021-04-09 05:02:05.600
# 313399   2021-04-09 05:15:05.000
# Name: datetime, Length: 313400, dtype: datetime64[ns]

# %%
events = list(df.index)

# %%
pyplot.plot(datetimes, events)
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
# Out:
# Text(0, 0.5, 'cumulative events')

# %%
magnitudes = df['magnitude']

# %%
pyplot.plot(datetimes, magnitudes)
pyplot.title('magnitude by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
# Out:
# Text(0, 0.5, 'magnitude')

# %%
pyplot.plot(datetimes, events)
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.plot(datetimes, magnitudes)
pyplot.title('magnitude by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.legend(['cumulative events', 'magnitudes'])

# %%
pyplot.plot(datetimes, events, label='cumulative events')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.plot(datetimes, magnitudes, label='magnitudes')
pyplot.title('magnitude by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.legend()

# %% [markdown]
# ## fmt = 'marker line color'
# '--k' 'b'

# %%
pyplot.plot(datetimes, events, '--k', label='cumulative events')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.plot(datetimes, magnitudes, 'b', label='magnitudes')
pyplot.title('magnitude by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.legend()

# %%
df
# Out:
#                       datetime  latitude  lotitude  depth  magnitude
# id
# 0      1964-02-24 23:30:25.000   38.9000   23.9000     10        5.3
# 1      1964-04-11 16:00:00.000   39.7500   25.2500     10        5.7
# 2      1964-04-21 08:14:40.000   38.5000   22.2500     10        4.5
# 3      1964-04-24 03:49:58.000   38.0000   21.8000     10        5.0
# 4      1964-04-29 04:21:00.000   39.2500   23.7500     10        5.8
# ...                        ...       ...       ...    ...        ...
# 313395 2021-04-09 05:00:07.400   39.7856   21.9081      5        0.6
# 313396 2021-04-09 05:00:21.900   39.7920   21.9328      5        1.5
# 313397 2021-04-09 05:01:06.500   39.7160   22.1947      8        1.0
# 313398 2021-04-09 05:02:05.600   39.7929   21.9154      6        1.0
# 313399 2021-04-09 05:15:05.000   39.8007   21.8948      7        1.2
#
# [313400 rows x 5 columns]

# %%
df = df.reset_index().set_index('datetime')

# %%
df
# Out:
#                              id  latitude  lotitude  depth  magnitude
# datetime
# 1964-02-24 23:30:25.000       0   38.9000   23.9000     10        5.3
# 1964-04-11 16:00:00.000       1   39.7500   25.2500     10        5.7
# 1964-04-21 08:14:40.000       2   38.5000   22.2500     10        4.5
# 1964-04-24 03:49:58.000       3   38.0000   21.8000     10        5.0
# 1964-04-29 04:21:00.000       4   39.2500   23.7500     10        5.8
# ...                         ...       ...       ...    ...        ...
# 2021-04-09 05:00:07.400  313395   39.7856   21.9081      5        0.6
# 2021-04-09 05:00:21.900  313396   39.7920   21.9328      5        1.5
# 2021-04-09 05:01:06.500  313397   39.7160   22.1947      8        1.0
# 2021-04-09 05:02:05.600  313398   39.7929   21.9154      6        1.0
# 2021-04-09 05:15:05.000  313399   39.8007   21.8948      7        1.2
#
# [313400 rows x 5 columns]

# %%
# Out:
#                          event  latitude  lotitude  depth  magnitude
# datetime
# 1999-01-01 03:19:31.200  33606     35.34     24.28     16        3.8
# 1999-01-01 04:39:51.900  33607     37.27     20.58      5        3.1
# 1999-01-02 09:35:36.700  33608     36.02     21.37     13        3.1
# 1999-01-02 09:59:48.000  33609     37.73     21.26      5        2.8
# 1999-01-02 18:48:57.500  33610     38.91     21.06      5        3.0
# ...                        ...       ...       ...    ...        ...
# 2009-12-31 14:24:01.200  88348     37.47     21.83     21        2.8
# 2009-12-31 14:50:29.600  88349     34.67     24.42     15        3.4
# 2009-12-31 17:27:45.800  88350     35.68     23.47      5        2.9
# 2009-12-31 20:43:12.900  88351     36.37     21.61     11        3.2
# 2009-12-31 20:58:40.800  88352     39.70     20.76     18        2.8
#
# [54747 rows x 5 columns]

# %%
df_1990s = df['1990-01-01 00:00:00':'1999-12-31 23:59:59'].copy()

# %%
df_2000s = df['2000-01-01 00:00:00':'2009-12-31 23:59:59'].copy()

# %%
df_1990s
# Out:
#                             id  latitude  lotitude  depth  magnitude
# datetime
# 1990-01-01 03:52:48.500  16953     36.09     22.29      1        3.3
# 1990-01-02 08:02:00.400  16954     38.55     24.48      6        2.7
# 1990-01-02 20:35:43.100  16955     38.58     24.26     14        4.5
# 1990-01-02 20:41:26.000  16956     38.53     24.42     20        2.8
# 1990-01-02 20:42:06.900  16957     38.55     24.15      6        2.6
# ...                        ...       ...       ...    ...        ...
# 1999-12-30 14:14:10.400  36091     37.63     21.23     10        2.9
# 1999-12-30 15:19:17.200  36092     39.15     26.90     15        3.4
# 1999-12-30 23:04:59.200  36093     36.57     25.49     27        3.4
# 1999-12-31 04:45:42.300  36094     35.70     24.10     33        3.1
# 1999-12-31 10:56:55.800  36095     37.45     22.10      5        3.5
#
# [19143 rows x 5 columns]

# %%
df_1990s['event'] = 1
df_1990s['event'] = df_1990s['event'].cumsum()

# %%
df_1990s
# Out:
#                             id  latitude  lotitude  depth  magnitude  event
# datetime
# 1990-01-01 03:52:48.500  16953     36.09     22.29      1        3.3      1
# 1990-01-02 08:02:00.400  16954     38.55     24.48      6        2.7      2
# 1990-01-02 20:35:43.100  16955     38.58     24.26     14        4.5      3
# 1990-01-02 20:41:26.000  16956     38.53     24.42     20        2.8      4
# 1990-01-02 20:42:06.900  16957     38.55     24.15      6        2.6      5
# ...                        ...       ...       ...    ...        ...    ...
# 1999-12-30 14:14:10.400  36091     37.63     21.23     10        2.9  19139
# 1999-12-30 15:19:17.200  36092     39.15     26.90     15        3.4  19140
# 1999-12-30 23:04:59.200  36093     36.57     25.49     27        3.4  19141
# 1999-12-31 04:45:42.300  36094     35.70     24.10     33        3.1  19142
# 1999-12-31 10:56:55.800  36095     37.45     22.10      5        3.5  19143
#
# [19143 rows x 6 columns]

# %%
df_2000s['event'] = 1
df_2000s['event'] = df_2000s['event'].cumsum()

# %%
df_2000s
# Out:
#                             id  latitude  lotitude  depth  magnitude  event
# datetime
# 2000-01-01 01:19:28.300  36096     41.95     20.63      5        4.8      1
# 2000-01-01 04:02:28.400  36097     35.54     22.76     22        3.7      2
# 2000-01-01 05:13:59.100  36098     38.97     26.10     35        3.3      3
# 2000-01-01 05:17:12.900  36099     38.89     25.85     22        3.3      4
# 2000-01-01 05:56:07.300  36100     39.21     27.30     10        3.6      5
# ...                        ...       ...       ...    ...        ...    ...
# 2009-12-31 14:24:01.200  88348     37.47     21.83     21        2.8  52253
# 2009-12-31 14:50:29.600  88349     34.67     24.42     15        3.4  52254
# 2009-12-31 17:27:45.800  88350     35.68     23.47      5        2.9  52255
# 2009-12-31 20:43:12.900  88351     36.37     21.61     11        3.2  52256
# 2009-12-31 20:58:40.800  88352     39.70     20.76     18        2.8  52257
#
# [52257 rows x 6 columns]

# %%
pyplot.plot(df_1990s.index, df_1990s['event'])
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
# Out:
# Text(0, 0.5, 'cumulative events')

# %%
pyplot.plot(df_2000s.index, df_2000s['event'])
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
# Out:
# Text(0, 0.5, 'cumulative events')

# %%
pyplot.plot(df_1990s.index, df_1990s['event'], label='1990s')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.plot(df_2000s.index, df_2000s['event'], label='2000s')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.legend(loc='upper left')
# HOW TO SAVE THE FIGURE PROGRAMMATICALY
pyplot.savefig('plot.png')

# %%
df_2000s['event'].resample('Y').plot()
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
# Out:
# Text(0, 0.5, 'cumulative events')

# %%
df_1990s['event'].resample('Y').plot(label='1990s')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
df_2000s['event'].resample('Y').plot(label='2000s')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.tight_layout()
pyplot.grid(True)
pyplot.legend()

# %%
pyplot.plot(df_2000s.index, df_2000s['event'], color='#444444', linestyle='-', marker='', label='2000s')
pyplot.title('cumulative events by datetime')
pyplot.xlabel('datetime')
pyplot.ylabel('cumulative events')
pyplot.grid(True)

# %%
pyplot.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
pyplot.style.use('seaborn')

# %% [markdown]
# # xkcd STYLE

# %%
pyplot.xkcd()

# %%
df_orpheus = df['2021-01-18 00:00:00':'2021-01-18 23:59:59'].copy()

# %%
df_orpheus.count()
# Out:
# id           82
# latitude     82
# lotitude     82
# depth        82
# magnitude    82
# dtype: int64

# %%
pyplot.rcdefaults()

# %%
pyplot.style.use('seaborn')
pyplot.plot(df_orpheus.index, df_orpheus['magnitude'])
pyplot.title('earthquake magnitudes the day Orpheus was born')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.grid(True)

# %%
pyplot.style.use('seaborn')
pyplot.scatter(df_orpheus.index, df_orpheus['magnitude'], s=16, marker='o', 
    edgecolors='black', linewidth=0.1, alpha=0.75) # s: size
pyplot.title('earthquake magnitudes the day Orpheus was born')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.grid(True)

# %% [markdown]
# let's also assign the depth

# %%
df_orpheus['depth']
# Out:
# datetime
# 2021-01-18 00:03:11.500     14
# 2021-01-18 00:19:16.500     15
# 2021-01-18 00:48:15.100      7
# 2021-01-18 00:51:00.000      6
# 2021-01-18 01:13:10.600    124
#                           ...
# 2021-01-18 22:09:19.900     12
# 2021-01-18 22:23:09.400      9
# 2021-01-18 22:55:57.300     32
# 2021-01-18 23:10:07.100     10
# 2021-01-18 23:44:07.200      8
# Name: depth, Length: 82, dtype: int64

# %%
colors = list(df_orpheus['depth'])

# %%
pyplot.style.use('seaborn')
pyplot.scatter(df_orpheus.index, df_orpheus['magnitude'], s=16, marker='o', 
    edgecolors='black', linewidth=0.1, alpha=0.90, c=colors) # s: size, c: colors
pyplot.title('earthquake magnitudes the day Orpheus was born')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.grid(True)

# %% [markdown]
# we can use a color map

# %%
pyplot.style.use('seaborn')
pyplot.scatter(df_orpheus.index, df_orpheus['magnitude'], s=16, marker='o', 
    edgecolors='black', linewidth=0.1, alpha=0.90, cmap='Greens', c=colors) # s: size, c: colors
pyplot.title('earthquake magnitudes the day Orpheus was born')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.grid(True)
cbar = pyplot.colorbar()
cbar.set_label('depth (km)')

# %%
df_orpheus['depth']
# Out:
# datetime
# 2021-01-18 00:03:11.500     14
# 2021-01-18 00:19:16.500     15
# 2021-01-18 00:48:15.100      7
# 2021-01-18 00:51:00.000      6
# 2021-01-18 01:13:10.600    124
#                           ...
# 2021-01-18 22:09:19.900     12
# 2021-01-18 22:23:09.400      9
# 2021-01-18 22:55:57.300     32
# 2021-01-18 23:10:07.100     10
# 2021-01-18 23:44:07.200      8
# Name: depth, Length: 82, dtype: int64

# %%
sizes = list(df_orpheus['magnitude'])
colors = list(df_orpheus['latitude'])

# %%
pyplot.style.use('seaborn')
sctr = pyplot.scatter(df_orpheus.index, df_orpheus['depth'], s=sizes, marker='o', 
    edgecolors='black', linewidth=0.1, alpha=0.90, c=colors) # s: size, c: colors
pyplot.title('earthquakes the day Orpheus was born')
pyplot.xlabel('datetime')
pyplot.ylabel('depth')

sctr.axes.invert_yaxis()

# could also be done with the gcf() method (get currebt figure)
# pyplot.gcf().axes.invert_axis()

pyplot.colorbar().set_label('Latitude')

pyplot.grid(True)

# %% [markdown]
# log Scale!

# %%
pyplot.style.use('seaborn')
pyplot.scatter(df_orpheus.index, df_orpheus['magnitude'], s=sizes, marker='o', 
    edgecolors='black', linewidth=0.1, alpha=0.90) # s: size, c: colors

pyplot.yscale('log')

pyplot.title('earthquake magnitudes the day Orpheus was born')
pyplot.xlabel('datetime')
pyplot.ylabel('magnitude')
pyplot.grid(True)

# %%
dt_list = list(df_orpheus.index)

# %%
pyplot.plot_date(df_orpheus.index, df_orpheus['magnitude'], linestyle='solid')
pyplot.gcf().autofmt_xdate()

# %% [markdown]
# change the format of the dates

# %%
from matplotlib import dates

# %%
date_format = dates.DateFormatter('%H:%M:%S')
pyplot.plot_date(df_orpheus.index, df_orpheus['magnitude'], linestyle='solid')
pyplot.gca().xaxis.set_major_formatter(date_format) # get current axes
pyplot.gcf().autofmt_xdate()
